# %% [markdown]
# # Survival of patients with colorectal liver metastases treated with and
#
# without preoperative chemotherapy: propensity score-matched study
#
# RPythonStudy (KIRAMS)
#
# ### Introduction
#
# ### Methods

# %%
source("C:/R/Projects/R-4.4.1-RPythonStudy_Demo/source/my_functions.R")
library(readxl)
HAN_raw <- read_excel("C:/R/Projects/R-4.4.1-RPythonStudy_Demo/raw_data/deidentified_han20230213.xlsx")
Total_number_of_patients <- nrow(HAN_raw)
HAN_NA_variable_cleaned<-my_NA_variable_clean(HAN_raw, 5)
# Out:
# Columns with NAs:
# 과거.암병력: 142 NAs
# Comobidity..MI.CHF.PVD.CVA.dementia.COPD.CD.PU.LD.DM.hemipl.CKD..: 78 NAs
# preHR_CA199: 4 NAs
# COMMENT: 150 NAs
# Columns with NAs:
# preHR_CA199: 4 NAs

# %% [markdown]
# ### Results
#
# The total number of patients was 156. The log transformed histogram for preHR_CA19-9 is shown in Figure 1.

# %%
my_histogram_log_transformation_with_outliers (HAN_NA_clearned, "preHR_CA199")
# Out:
# ...
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ...
# ℹ Please use `linewidth` instead.

# %% [markdown]
# ### Discussion
#
# ### Conclusion
#
# The title of this demo manuscript was inspired by the paper of de Graaff MR in in 2023 ([Graaff et al. 2023](#ref-RN670)).
#
# Graaff, M. R. de, J. M. Klaase, R. M. van Dam, K. F. D. Kuhlmann, G. Kazemier, R. J. Swijnenburg, A. K. E. Elfrink, et al. 2023. “Survival of Patients with Colorectal Liver Metastases Treated with and Without Preoperative Chemotherapy: Nationwide Propensity Score-Matched Study.” Journal Article. *Eur J Surg Oncol* 49 (9): 106932. <https://doi.org/10.1016/j.ejso.2023.05.007>.
